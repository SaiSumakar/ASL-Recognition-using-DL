# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
from math import ceil
import sklearn
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import load_img, img_to_array, array_to_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
# Out:
# C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\framework\dtypes.py:585: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 7
#       5 from math import ceil
#       6 import sklearn
# ----> 7 import tensorflow as tf
#       8 from tensorflow.keras.models import Sequential, load_model
#       9 from tensorflow.keras.layers import Convolution2D, MaxPooling2D, Flatten, Dense, Dropout
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\__init__.py:46
#      41 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
#      43 # pylint: enable=wildcard-import
#      44
#      45 # Bring in subpackages.
# ---> 46 from tensorflow.python import data
#      47 from tensorflow.python import distribute
#      48 # from tensorflow.python import keras
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\data\__init__.py:25
#      22 from __future__ import print_function
#      24 # pylint: disable=unused-import
# ---> 25 from tensorflow.python.data import experimental
#      26 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      27 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\data\experimental\__init__.py:97
#      94 from __future__ import print_function
#      96 # pylint: disable=unused-import
# ---> 97 from tensorflow.python.data.experimental import service
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\data\experimental\service\__init__.py:353
#     350 from __future__ import division
#     351 from __future__ import print_function
# --> 353 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     354 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     355 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\data\experimental\ops\data_service_ops.py:26
#      24 from tensorflow.python import tf2
#      25 from tensorflow.python.compat import compat
# ---> 26 from tensorflow.python.data.experimental.ops import compression_ops
#      27 from tensorflow.python.data.experimental.ops.distribute_options import AutoShardPolicy
#      28 from tensorflow.python.data.experimental.ops.distribute_options import ExternalStatePolicy
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\data\experimental\ops\compression_ops.py:20
#      17 from __future__ import division
#      18 from __future__ import print_function
# ---> 20 from tensorflow.python.data.util import structure
#      21 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      24 def compress(element):
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\data\util\structure.py:26
#      23 import six
#      24 import wrapt
# ---> 26 from tensorflow.python.data.util import nest
#      27 from tensorflow.python.framework import composite_tensor
#      28 from tensorflow.python.framework import ops
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\data\util\nest.py:40
#      36 from __future__ import print_function
#      38 import six as _six
# ---> 40 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      41 from tensorflow.python.util import _pywrap_utils
#      42 from tensorflow.python.util import nest
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\framework\sparse_tensor.py:28
#      26 from tensorflow.python import tf2
#      27 from tensorflow.python.framework import composite_tensor
# ---> 28 from tensorflow.python.framework import constant_op
#      29 from tensorflow.python.framework import dtypes
#      30 from tensorflow.python.framework import ops
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\framework\constant_op.py:29
#      27 from tensorflow.core.framework import types_pb2
#      28 from tensorflow.python.eager import context
# ---> 29 from tensorflow.python.eager import execute
#      30 from tensorflow.python.framework import dtypes
#      31 from tensorflow.python.framework import op_callbacks
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\eager\execute.py:27
#      25 from tensorflow.python import pywrap_tfe
#      26 from tensorflow.python.eager import core
# ---> 27 from tensorflow.python.framework import dtypes
#      28 from tensorflow.python.framework import ops
#      29 from tensorflow.python.framework import tensor_shape
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\tensorflow\python\framework\dtypes.py:585
#     556     _NP_TO_TF[pdt] = next(
#     557         _NP_TO_TF[dt] for dt in _NP_TO_TF if dt == pdt().dtype)  # pylint: disable=no-value-for-parameter
#     559 TF_VALUE_DTYPES = set(_NP_TO_TF.values())
#     561 _TF_TO_NP = {
#     562     types_pb2.DT_HALF:
#     563         np.float16,
#     564     types_pb2.DT_FLOAT:
#     565         np.float32,
#     566     types_pb2.DT_DOUBLE:
#     567         np.float64,
#     568     types_pb2.DT_INT32:
#     569         np.int32,
#     570     types_pb2.DT_UINT8:
#     571         np.uint8,
#     572     types_pb2.DT_UINT16:
#     573         np.uint16,
#     574     types_pb2.DT_UINT32:
#     575         np.uint32,
#     576     types_pb2.DT_UINT64:
#     577         np.uint64,
#     578     types_pb2.DT_INT16:
#     579         np.int16,
#     580     types_pb2.DT_INT8:
#     581         np.int8,
#     582     # NOTE(touts): For strings we use np.object as it supports variable length
#     583     # strings.
#     584     types_pb2.DT_STRING:
# --> 585         np.object,
#     586     types_pb2.DT_COMPLEX64:
#     587         np.complex64,
#     588     types_pb2.DT_COMPLEX128:
#     589         np.complex128,
#     590     types_pb2.DT_INT64:
#     591         np.int64,
#     592     types_pb2.DT_BOOL:
#     593         np.bool_,
#     594     types_pb2.DT_QINT8:
#     595         _np_qint8,
#     596     types_pb2.DT_QUINT8:
#     597         _np_quint8,
#     598     types_pb2.DT_QINT16:
#     599         _np_qint16,
#     600     types_pb2.DT_QUINT16:
#     601         _np_quint16,
#     602     types_pb2.DT_QINT32:
#     603         _np_qint32,
#     604     types_pb2.DT_BFLOAT16:
#     605         _np_bfloat16,
#     606
#     607     # Ref types
#     608     types_pb2.DT_HALF_REF:
#     609         np.float16,
#     610     types_pb2.DT_FLOAT_REF:
#     611         np.float32,
#     612     types_pb2.DT_DOUBLE_REF:
#     613         np.float64,
#     614     types_pb2.DT_INT32_REF:
#     615         np.int32,
#     616     types_pb2.DT_UINT32_REF:
#     617         np.uint32,
#     618     types_pb2.DT_UINT8_REF:
#     619         np.uint8,
#     620     types_pb2.DT_UINT16_REF:
#     621         np.uint16,
#     622     types_pb2.DT_INT16_REF:
#     623         np.int16,
#     624     types_pb2.DT_INT8_REF:
#     625         np.int8,
#     626     types_pb2.DT_STRING_REF:
#     627         np.object,
#     628     types_pb2.DT_COMPLEX64_REF:
#     629         np.complex64,
#     630     types_pb2.DT_COMPLEX128_REF:
#     631         np.complex128,
#     632     types_pb2.DT_INT64_REF:
#     633         np.int64,
#     634     types_pb2.DT_UINT64_REF:
#     635         np.uint64,
#     636     types_pb2.DT_BOOL_REF:
#     637         np.bool,
#     638     types_pb2.DT_QINT8_REF:
#     639         _np_qint8,
#     640     types_pb2.DT_QUINT8_REF:
#     641         _np_quint8,
#     642     types_pb2.DT_QINT16_REF:
#     643         _np_qint16,
#     644     types_pb2.DT_QUINT16_REF:
#     645         _np_quint16,
#     646     types_pb2.DT_QINT32_REF:
#     647         _np_qint32,
#     648     types_pb2.DT_BFLOAT16_REF:
#     649         _np_bfloat16,
#     650 }
#     652 _QUANTIZED_DTYPES_NO_REF = frozenset([qint8, quint8, qint16, quint16, qint32])
#     653 _QUANTIZED_DTYPES_REF = frozenset(
#     654     [qint8_ref, quint8_ref, qint16_ref, quint16_ref, qint32_ref])
#
# File C:\anaconda3\envs\emenvi\lib\site-packages\numpy\__init__.py:324, in __getattr__(attr)
#     319     warnings.warn(
#     320         f"In the future `np.{attr}` will be defined as the "
#     321         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     323 if attr in __former_attrs__:
# --> 324     raise AttributeError(__former_attrs__[attr])
#     326 if attr == 'testing':
#     327     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'object'.
# `np.object` was a deprecated alias for the builtin `object`. To avoid this error in existing code, use `object` by itself. Doing this will not modify any behavior and is safe.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
import tensorflow as tf

tf.__version__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 3
#       1 import tensorflow as tf
# ----> 3 tf.__version__
#
# AttributeError: module 'tensorflow' has no attribute '__version__'

# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\anaconda3\envs\emenvi\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (20210226132247)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.68.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.35.1)
# Requirement already satisfied: rich in c:\anaconda3\envs\emenvi\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\anaconda3\envs\emenvi\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\anaconda3\envs\emenvi\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda3\envs\emenvi\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\envs\emenvi\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\envs\emenvi\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\emenvi\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\anaconda3\envs\emenvi\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.6)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\anaconda3\envs\emenvi\lib\site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\anaconda3\envs\emenvi\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda3\envs\emenvi\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: zipp>=3.20 in c:\anaconda3\envs\emenvi\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda3\envs\emenvi\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)

# %%
import torch

print("Number of GPU: ", torch.cuda.device_count())
print("GPU Name: ", torch.cuda.get_device_name())


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Number of GPU:  1
# GPU Name:  NVIDIA GeForce RTX 3050 Laptop GPU
# Using device: cuda
